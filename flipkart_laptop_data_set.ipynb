# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the dataset
data=pd.read_csv("C:\\Users\\DELL\\Downloads\\Flipkart laptops_info.csv",error_bad_lines=False)
data
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_32100\2552722159.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data=pd.read_csv("C:\\Users\\DELL\\Downloads\\Flipkart laptops_info.csv",error_bad_lines=False)
# ...

# %%
data.columns
# Out:
# Index(['ProductName', 'Stars', 'Ratings', 'Reviews', 'Current_Price', 'MRP',
#        'Proccessor', 'Ram', 'Storage', 'ImageURL'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=681, step=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 681 entries, 0 to 680
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ProductName    681 non-null    object
#  1   Stars          681 non-null    float64
#  2   Ratings        681 non-null    int64
#  3   Reviews        681 non-null    int64
#  4   Current_Price  681 non-null    int64
#  5   MRP            681 non-null    int64
#  6   Proccessor     681 non-null    object
#  7   Ram            681 non-null    object
#  8   Storage        681 non-null    object
#  9   ImageURL       681 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 53.3+ KB

# %%
data.shape
# Out:
# (681, 10)

# %%
data.isnull().sum()
# Out:
# ProductName      0
# Stars            0
# Ratings          0
# Reviews          0
# Current_Price    0
# MRP              0
# Proccessor       0
# Ram              0
# Storage          0
# ImageURL         0
# dtype: int64

# %%
data.describe()
# Out:
#             Stars       Ratings      Reviews  Current_Price            MRP
# count  681.000000    681.000000   681.000000     681.000000     681.000000
# mean     3.393392    817.650514   102.396476   48240.491924   62572.709251
# std      1.644590   1909.163189   242.605686   13941.846996   19504.876499
# min      0.000000      0.000000     0.000000   15990.000000       0.000000
# 25%      3.700000      8.000000     0.000000   37250.000000   50000.000000
# 50%      4.200000     78.000000    10.000000   47990.000000   61590.000000
# 75%      4.300000    505.000000    61.000000   59990.000000   76473.000000
# max      5.000000  17745.000000  2300.000000  102000.000000  136990.000000

# %%
data.value_counts()
# Out:
# ProductName                                   Stars  Ratings  Reviews  Current_Price  MRP    Proccessor                                                                Ram                                            Storage                                                 ImageURL
# realme Book(Slim) Intel Evo Core i5 11th Gen  4.4    7067     949      59990          69999  Powered by 11th Gen Intel Evo Core i5 Processor                           Microsoft Office 2019 Home & Student Included  Intel Core i5 Processor (11th Gen)                      https://rukminim1.flixcart.com/image/312/312/ksez24w0/computer/h/8/9/rmnb1001-thin-and-light-laptop-realme-original-imag5zhgcstmjbxg.jpeg?q=70       29
# ...

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 676    False
# 677    False
# 678    False
# 679    False
# 680    False
# Length: 681, dtype: bool

# %%
data=data.drop_duplicates()

# %%
data.head(10)
# Out:
#                                          ProductName  Stars  Ratings  Reviews  \
# 0                  Lenovo IdeaPad 3 Core i3 10th Gen    4.3        8        0
# 1       realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 2           ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 3               HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 4                     Lenovo Intel Celeron Dual Core    4.1      366       35
# 5  ASUS TUF Gaming A17 with 90Whr Battery Ryzen 5...    4.4     1340      166
# 6              acer Aspire 3 Ryzen 3 Dual Core 3250U    4.2      263       55
# 7                      HP 14s Intel Core i3 11th Gen    4.2     1556      137
# 8                     Lenovo V15 G2 Core i3 11th Gen    3.8       22        1
# 9                     RedmiBook Pro Core i5 11th Gen    4.1     3641      430
#
#    Current_Price    MRP                                       Proccessor  \
# ...

# %%
#largest Mrp
data.nlargest(5,'MRP')
# Out:
#                                 ProductName  Stars  Ratings  Reviews  \
# 539         ASUS Ryzen 7 Octa Core 10th Gen    0.0        0        0
# 501   Lenovo ThinkBook 13s Core i5 11th Gen    4.0       91        9
# 373   Lenovo IdeaPad 5 Pro Core i5 11th Gen    4.1       22        5
# 506  Lenovo IdeaPad Gaming Core i7 10th Gen    4.5      112        6
# 670          DELL Inspiron Core i5 11th Gen    4.2      166       14
#
#      Current_Price     MRP                                  Proccessor  \
# 539         102000  136990  AMD Ryzen 7 Octa Core Processor (10th Gen)
# 501          67990  121608          Intel Core i5 Processor (11th Gen)
# 373          69000  113290          Intel Core i5 Processor (11th Gen)
# 506          75989  102090          Intel Core i7 Processor (10th Gen)
# 670          67990  101639          Intel Core i5 Processor (11th Gen)
#
#                 Ram     Storage  \
# 539  16 GB DDR4 RAM  512 GB SSD
# 501   8 GB DDR4 RAM    1 TB SSD
# ...

# %%
#smallest Mrp Products
data.nsmallest(5,'MRP')
# Out:
#                                            ProductName  Stars  Ratings  \
# 199         HP Pavilion Gaming Ryzen 5 Quad Core 3550H    4.4     2207
# 403         DELL Inspiron 3505 Ryzen 7 Quad Core 3700U    4.4       76
# 404                    acer Aspire 3 Pentium Quad Core    0.0        0
# 421                                         Lenovo B50    3.8       78
# 458  Primebook 4G Enabled Android Based MediaTek Ko...    0.0        0
#
#      Reviews  Current_Price  MRP                                Proccessor  \
# 199      248          59990    0           AMD Ryzen 5 Quad Core Processor
# 403       14          71000    0           AMD Ryzen 7 Quad Core Processor
# 404        0          37990    0         Intel Pentium Quad Core Processor
# 421       17          52490    0         Intel Core i5 Processor (4th Gen)
# 458        0          24990    0  MediaTek MediaTek Kompanio 500 Processor
#
#                  Ram                       Storage  \
# ...

# %%
data.groupby('ProductName')['ProductName'].count().sort_values( ascending=False)
# Out:
# ProductName
# DELL Inspiron Core i5 11th Gen                  16
# DELL Inspiron Core i3 11th Gen                  11
# HP Core i3 11th Gen                              9
# Lenovo Core i3 11th Gen                          9
# DELL Inspiron Ryzen 3 Dual Core 3250U            8
#                                                 ..
# HP Pavilion Gaming Ryzen 5 Hexa Core 4600H       1
# HP Pavilion Gaming Ryzen 5 Quad Core 3550H       1
# ASUS Vivobook 14 Core i5 10th Gen                1
# ASUS Vivobook 14 Core i3 11th Gen                1
# realme Book(Slim) Intel Evo Core i5 11th Gen     1
# Name: ProductName, Length: 342, dtype: int64

# %%
data['Ram'].groupby(data['Ram']).count()
# Out:
# Ram
# 16 GB DDR4 RAM                                            64
# 16 GB LPDDR4X RAM                                          7
# 16 GB LPDDR5 RAM                                           1
# 4 GB DDR3 RAM                                              4
# 4 GB DDR4 RAM                                             68
# 4 GB LPDDR4 RAM                                           11
# 4 GB LPDDR4X RAM                                           6
# 64 GB DDR4 RAM                                             1
# 8 GB DDR3 RAM                                              2
# 8 GB DDR4 RAM                                            364
# 8 GB DDR5 RAM                                              1
# 8 GB LPDDR4X RAM                                          25
# AMD Ryzen 5 Hexa Core Processor                            2
# Intel Core i5 Processor (11th Gen)                         1
# Intel Core i7 Processor (7th Gen)                          1
# ...

# %%
data
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 0               Lenovo IdeaPad 3 Core i3 10th Gen    4.3        8        0
# 1    realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 2        ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 3            HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 4                  Lenovo Intel Celeron Dual Core    4.1      366       35
# ..                                            ...    ...      ...      ...
# 676       Infinix INBook X2 Plus Core i3 11th Gen    4.1      146       32
# 677         DELL Inspiron Ryzen 3 Dual Core 3250U    4.5        4        0
# 678                          MSI Core i3 12th Gen    0.0        0        0
# 679                         ASUS Core i3 10th Gen    4.7       12        0
# 680           HP Pavilion Ryzen 5 Hexa Core 5625U    4.5      199       15
#
# ...

# %%
#drop the URL Column
data=data.drop('ImageURL',axis=1)

# %%
data
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 0               Lenovo IdeaPad 3 Core i3 10th Gen    4.3        8        0
# 1    realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 2        ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 3            HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 4                  Lenovo Intel Celeron Dual Core    4.1      366       35
# ..                                            ...    ...      ...      ...
# 676       Infinix INBook X2 Plus Core i3 11th Gen    4.1      146       32
# 677         DELL Inspiron Ryzen 3 Dual Core 3250U    4.5        4        0
# 678                          MSI Core i3 12th Gen    0.0        0        0
# 679                         ASUS Core i3 10th Gen    4.7       12        0
# 680           HP Pavilion Ryzen 5 Hexa Core 5625U    4.5      199       15
#
# ...

# %%
data['Ratings'].max()
# Out:
# 17745

# %%
#find the max ratings
data.loc[(data['Ratings']>=17745)]
# Out:
#                 ProductName  Stars  Ratings  Reviews  Current_Price    MRP  \
# 637  ASUS Celeron Dual Core    3.7    17745     2300          22990  30990
#
#                             Proccessor            Ram   Storage
# 637  Intel Celeron Dual Core Processor  4 GB DDR4 RAM  1 TB HDD

# %%
#top 10 ratings
data.sort_values(by='Ratings',ascending=False).head(10)
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 637                        ASUS Celeron Dual Core    3.7    17745     2300
# 3            HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 2        ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 226      ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 1    realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 604   Lenovo Ideapad S145 Ryzen 3 Dual Core 3200U    3.9     6201      932
# 92       ASUS VivoBook 15 (2022) Core i5 10th Gen    4.3     6061      519
# 536                         ASUS Core i5 10th Gen    4.3     6061      519
# 621           HP Chromebook MediaTek Kompanio 500    3.8     5944      681
# 667           HP Chromebook MediaTek Kompanio 500    3.8     5944      681
#
#      Current_Price    MRP                                       Proccessor  \
# ...

# %%
#sort All Values By Stars
data.sort_values(by='Stars',ascending=False).head(25)
# Out:
#                                          ProductName  Stars  Ratings  Reviews  \
# 48               HP Pavilion Ryzen 5 Hexa Core 5625U    5.0        3        1
# 349                          Lenovo Core i3 10th Gen    5.0        1        1
# 124         ASUS Vivobook 14 (2022) Core i5 12th Gen    5.0        4        0
# 335                          Lenovo Core i3 10th Gen    5.0        4        0
# 267            acer Aspire 5 Ryzen 7 Octa Core 5700U    5.0        3        0
# 66                 HP Victus Ryzen 5 Hexa Core 5600H    5.0        5        1
# 78            ASUS Vivobook 16X Ryzen 5 Hexa Core R5    4.9        7        0
# 76          ASUS Vivobook 14 (2022) Core i5 12th Gen    4.8       14        3
# 108           ASUS VivoBook Flip 14 Core i5 11th Gen    4.8       20        1
# 288                            DELL Core i3 12th Gen    4.7        3        0
# 679                            ASUS Core i3 10th Gen    4.7       12        0
# ...

# %%
data
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 0               Lenovo IdeaPad 3 Core i3 10th Gen    4.3        8        0
# 1    realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 2        ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 3            HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 4                  Lenovo Intel Celeron Dual Core    4.1      366       35
# ..                                            ...    ...      ...      ...
# 676       Infinix INBook X2 Plus Core i3 11th Gen    4.1      146       32
# 677         DELL Inspiron Ryzen 3 Dual Core 3250U    4.5        4        0
# 678                          MSI Core i3 12th Gen    0.0        0        0
# 679                         ASUS Core i3 10th Gen    4.7       12        0
# 680           HP Pavilion Ryzen 5 Hexa Core 5625U    4.5      199       15
#
# ...

# %%
#Compare Current_Price to MRP 
data['Price_diff']=np.where(data['Current_Price']==data['MRP'],0,data['MRP']-data['Current_Price'])

# %%
data['Price_diff']
# Out:
# 0      21800
# 1      10009
# 2      13000
# 3      10549
# 4      12000
#        ...
# 676     9000
# 677     9342
# 678    13500
# 679    11509
# 680     8546
# Name: Price_diff, Length: 576, dtype: int64

# %%
data
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 0               Lenovo IdeaPad 3 Core i3 10th Gen    4.3        8        0
# 1    realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 2        ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 3            HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 4                  Lenovo Intel Celeron Dual Core    4.1      366       35
# ..                                            ...    ...      ...      ...
# 676       Infinix INBook X2 Plus Core i3 11th Gen    4.1      146       32
# 677         DELL Inspiron Ryzen 3 Dual Core 3250U    4.5        4        0
# 678                          MSI Core i3 12th Gen    0.0        0        0
# 679                         ASUS Core i3 10th Gen    4.7       12        0
# 680           HP Pavilion Ryzen 5 Hexa Core 5625U    4.5      199       15
#
# ...

# %%
#Which is the highest Price Diff Product
data.nlargest(10,'Price_diff')
# Out:
#                                 ProductName  Stars  Ratings  Reviews  \
# 501   Lenovo ThinkBook 13s Core i5 11th Gen    4.0       91        9
# 145                 Lenovo Core i3 11th Gen    4.0       47        2
# 582       Lenovo Thinkbook Core i3 11th Gen    0.0        0        0
# 373   Lenovo IdeaPad 5 Pro Core i5 11th Gen    4.1       22        5
# 70   Lenovo IdeaPad Ryzen 5 Hexa Core 5500U    4.6        7        0
# 302     Nokia PureBook S14 Core i5 11th Gen    4.0      815      193
# 182          DELL Inspiron Core i5 11th Gen    4.2       17        3
# 277     Nokia PureBook X14 Core i5 10th Gen    4.4     1498      314
# 160    acer Nitro 5 Ryzen 5 Hexa Core 4600H    4.5     2345      270
# 89          Lenovo IdeaPad Core i5 11th Gen    4.4       41        3
#
#      Current_Price     MRP                                 Proccessor  \
# 501          67990  121608         Intel Core i5 Processor (11th Gen)
# ...

# %%
#Which Are the Smallest Price Diff Products
data.nsmallest(10,'Price_diff')
# Out:
#                                            ProductName  Stars  Ratings  \
# 403         DELL Inspiron 3505 Ryzen 7 Quad Core 3700U    4.4       76
# 505            Lenovo Ideapad Slim 5i Core i5 11th Gen    4.1      115
# 508                        HP Pavilion Core i5 7th Gen    4.0      205
# 199         HP Pavilion Gaming Ryzen 5 Quad Core 3550H    4.4     2207
# 421                                         Lenovo B50    3.8       78
# 608                                HP Core i3 10th Gen    4.0       45
# 404                    acer Aspire 3 Pentium Quad Core    0.0        0
# 559                           HP MediaTek Kompanio 500    0.0        0
# 458  Primebook 4G Enabled Android Based MediaTek Ko...    0.0        0
# 427                   DELL Vostro 3000 Core i5 8th Gen    4.0     1371
#
#      Reviews  Current_Price    MRP                                Proccessor  \
# 403       14          71000      0           AMD Ryzen 7 Quad Core Processor
# ...

# %%
#find the most used Proccessor
most_used_proccessor=data['Proccessor'].value_counts().to_frame().head(35)
most_used_proccessor
# Out:
#                                                     Proccessor
# Intel Core i3 Processor (11th Gen)                         102
# Intel Core i5 Processor (11th Gen)                          80
# AMD Ryzen 5 Hexa Core Processor                             67
# Intel Core i3 Processor (10th Gen)                          46
# AMD Ryzen 3 Dual Core Processor                             34
# Intel Core i5 Processor (12th Gen)                          31
# Intel Core i5 Processor (10th Gen)                          28
# Intel Celeron Dual Core Processor                           25
# AMD Ryzen 7 Octa Core Processor                             16
# AMD Ryzen 5 Quad Core Processor                             15
# Intel Core i3 Processor (12th Gen)                          13
# Intel Pentium Quad Core Processor                           10
# Intel Core i5 Processor (8th Gen)                           10
# AMD Athlon Dual Core Processor                               9
# ...

# %%
data['Proccessor'].value_counts().idxmax()
# Out:
# 'Intel Core i3 Processor (11th Gen)'

# %%
#Laptos used most common Proccessor List
most_popular_lap_pro=data[['ProductName','Proccessor']].value_counts().to_frame().head(35)
most_popular_lap_pro
# Out:
#                                                                                      0
# ProductName                                     Proccessor
# DELL Inspiron Core i5 11th Gen                  Intel Core i5 Processor (11th Gen)  16
# HP Core i3 11th Gen                             Intel Core i3 Processor (11th Gen)   9
# Lenovo Core i3 11th Gen                         Intel Core i3 Processor (11th Gen)   9
# DELL Inspiron Ryzen 3 Dual Core 3250U           AMD Ryzen 3 Dual Core Processor      8
# DELL Inspiron Core i3 11th Gen                  Intel Core i3 Processor (11th Gen)   8
# DELL Core i3 11th Gen                           Intel Core i3 Processor (11th Gen)   7
# DELL Core i5 11th Gen                           Intel Core i5 Processor (11th Gen)   7
# DELL Vostro Core i3 11th Gen                    Intel Core i3 Processor (11th Gen)   6
# Infinix X1 Slim Series Core i5 10th Gen         Intel Core i5 Processor (10th Gen)   5
# ...

# %%
data
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 0               Lenovo IdeaPad 3 Core i3 10th Gen    4.3        8        0
# 1    realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 2        ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 3            HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 4                  Lenovo Intel Celeron Dual Core    4.1      366       35
# ..                                            ...    ...      ...      ...
# 676       Infinix INBook X2 Plus Core i3 11th Gen    4.1      146       32
# 677         DELL Inspiron Ryzen 3 Dual Core 3250U    4.5        4        0
# 678                          MSI Core i3 12th Gen    0.0        0        0
# 679                         ASUS Core i3 10th Gen    4.7       12        0
# 680           HP Pavilion Ryzen 5 Hexa Core 5625U    4.5      199       15
#
# ...

# %%
#Most Used Ram
data['Ram'].value_counts().to_frame()
# Out:
#                                                     Ram
# 8 GB DDR4 RAM                                       364
# 4 GB DDR4 RAM                                        68
# 16 GB DDR4 RAM                                       64
# 8 GB LPDDR4X RAM                                     25
# 4 GB LPDDR4 RAM                                      11
# 16 GB LPDDR4X RAM                                     7
# 4 GB LPDDR4X RAM                                      6
# RAM & Storage: 8GB DDR4 & 512GB SSD                   5
# 4 GB DDR3 RAM                                         4
# RAM & Storage: 8GB DDR4 & 1TB + 256GB SSD             3
# AMD Ryzen 5 Hexa Core Processor                       2
# RAM & Storage: 8GB DDR4 (2 DIMM Slots) & 512GB SSD    2
# 8 GB DDR3 RAM                                         2
# RAM & Storage: 8GB DDR4 & 256GB SSD                   2
# RAM & Storage: 8GB DDR4 (2 DIMM Slots) & 256GB SSD    1
# Microsoft Office 2019 Home & Student Included         1
# ...

# %%
data['Storage'].value_counts().to_frame()
# Out:
#                                                     Storage
# 512 GB SSD                                              319
# 256 GB SSD                                               98
# 1 TB HDD                                                 54
# 1 TB HDD|256 GB SSD                                      37
# 128 GB SSD                                               12
# 1 TB SSD                                                  9
# 29.46 cm (11.6 inch) Touchscreen Display                  6
# Display: 15.6" FHD WVA AG Narrow Border                   4
# 29.46 cm (11.6 Inch) Display                              4
# Software: Win 11 + Office H&S 2021                        4
# 29.46 cm (11.6 inch) Display                              3
# 64 bit Windows 10 Operating System                        3
# Display: 15.6" FHD WVA AG 120Hz 250 nits Narrow...        3
# 35.56 cm (14 inch) Display                                2
# 35.56 cm (14 inch) Touchscreen Display                    2
# ...

# %%
# compare Ram and storage that Which Storage are most used in which Rams
data.groupby(['Ram','Storage'])['Storage'].count().to_frame()
# Out:
#                                                                                                        Storage
# Ram                                                Storage
# 16 GB DDR4 RAM                                     1 TB HDD|256 GB SSD                                       2
#                                                    1 TB SSD                                                  1
#                                                    512 GB SSD                                               61
# 16 GB LPDDR4X RAM                                  512 GB SSD                                                7
# 16 GB LPDDR5 RAM                                   512 GB SSD                                                1
# 4 GB DDR3 RAM                                      1 TB HDD                                                  1
#                                                    128 GB SSD                                                2
# ...

# %%
data
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 0               Lenovo IdeaPad 3 Core i3 10th Gen    4.3        8        0
# 1    realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 2        ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 3            HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 4                  Lenovo Intel Celeron Dual Core    4.1      366       35
# ..                                            ...    ...      ...      ...
# 676       Infinix INBook X2 Plus Core i3 11th Gen    4.1      146       32
# 677         DELL Inspiron Ryzen 3 Dual Core 3250U    4.5        4        0
# 678                          MSI Core i3 12th Gen    0.0        0        0
# 679                         ASUS Core i3 10th Gen    4.7       12        0
# 680           HP Pavilion Ryzen 5 Hexa Core 5625U    4.5      199       15
#
# ...

# %% [markdown]
# # Now Visualized The data

# %%
#Most Stars laptops
Product_popular_by_stars=data.sort_values(by='Stars',ascending=False).head(10)
Product_popular_by_stars
plt.figure(figsize=(15,8))
sns.set(style='dark')
plt.subplot(2,1,1)
ax=sns.barplot(x='Stars',y='ProductName',data=Product_popular_by_stars)
for bars in ax.containers:
    ax.bar_label(bars,fontsize=10)

# %%
#Most Rating laptops
Product_popular_by_Ratings=data.sort_values(by='Ratings',ascending=False).head(15)
Product_popular_by_Ratings
plt.figure(figsize=(20,8))
sns.set(style='dark')
ax=sns.barplot(x='Ratings',y='ProductName',data=Product_popular_by_Ratings)
for bars in ax.containers:
    ax.bar_label(bars,fontsize=20)

# %%
#Most Review laptops
Product_popular_by_Reviews=data.sort_values(by='Reviews',ascending=False).head(15)
Product_popular_by_Reviews
plt.figure(figsize=(20,8))
sns.set(style='dark')
ax=sns.barplot(x='Reviews',y='ProductName',data=Product_popular_by_Reviews)
for bars in ax.containers:
    ax.bar_label(bars,fontsize=20)

# %% [markdown]
# # in upper 3 Visualization i will try to show
# the most popular laptops among the peoples.

# %%
data
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 0               Lenovo IdeaPad 3 Core i3 10th Gen    4.3        8        0
# 1    realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 2        ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 3            HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 4                  Lenovo Intel Celeron Dual Core    4.1      366       35
# ..                                            ...    ...      ...      ...
# 676       Infinix INBook X2 Plus Core i3 11th Gen    4.1      146       32
# 677         DELL Inspiron Ryzen 3 Dual Core 3250U    4.5        4        0
# 678                          MSI Core i3 12th Gen    0.0        0        0
# 679                         ASUS Core i3 10th Gen    4.7       12        0
# 680           HP Pavilion Ryzen 5 Hexa Core 5625U    4.5      199       15
#
# ...

# %%
#top10 Lowest Price laptos
smallest=data.nsmallest(10,'Current_Price')
smallest
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 109  ASUS Chromebook Flip Touch Celeron Dual Core    4.0     1741      274
# 269            Avita SATUS S111 Celeron Dual Core    3.9      646       89
# 589                   Avita PURA APU Dual Core A6    3.7     1597      228
# 643                   Avita PURA APU Dual Core A6    3.7     1597      228
# 384                 Lenovo Athlon Dual Core 3050U    4.0        8        2
# 477             ASUS Chromebook Celeron Dual Core    3.6      385       50
# 496                 Lenovo Athlon Dual Core 3050U    0.0        0        0
# 510                 Lenovo Athlon Dual Core 3050U    0.0        0        0
# 532                         AXL Celeron Dual Core    0.0        0        0
# 23                       Lenovo Celeron Dual Core    3.8      204       17
#
#      Current_Price    MRP                         Proccessor              Ram  \
# ...

# %%
plt.figure(figsize=(15,8))
ax=sns.barplot(x='Current_Price',y='ProductName',data=smallest)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#top highest price laptops
top_highest_lap=data.nlargest(10,'Current_Price')
top_highest_lap
# Out:
#                                      ProductName  Stars  Ratings  Reviews  \
# 539              ASUS Ryzen 7 Octa Core 10th Gen    0.0        0        0
# 450  ASUS TUF GAMING A15 Ryzen 7 Octa Core 4800H    0.0        0        0
# 506       Lenovo IdeaPad Gaming Core i7 10th Gen    4.5      112        6
# 403   DELL Inspiron 3505 Ryzen 7 Quad Core 3700U    4.4       76       14
# 247               acer Aspire 7 Core i5 12th Gen    4.3      285       33
# 328               DELL Inspiron Core i5 11th Gen    4.3      118       10
# 361       ASUS VivoBook Flip 14 Core i5 11th Gen    4.5       65        5
# 367        SAMSUNG Galaxy Book2 Core i5 12th Gen    4.2       38        5
# 585              DELL DELL 5590 Core i5 10th Gen    0.0        0        0
# 172               DELL Inspiron Core i5 11th Gen    4.1       75        9
#
#      Current_Price     MRP                                  Proccessor  \
# 539         102000  136990  AMD Ryzen 7 Octa Core Processor (10th Gen)
# ...

# %%
plt.figure(figsize=(15,8))
ax=sns.barplot(x='Current_Price',y='ProductName',data=top_highest_lap)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [raw]
# # Here also, i will try to show most valuable laptops based on there current prices

# %% [markdown]
# # find the midrage value in current price
# data['Current_Price'].describe()

# %%
data['Current_Price'].describe()
# Out:
# count       576.000000
# mean      48032.821181
# std       14068.137839
# min       15990.000000
# 25%       37965.000000
# 50%       47060.000000
# 75%       59990.000000
# max      102000.000000
# Name: Current_Price, dtype: float64

# %%
#most midrange laptops
most_mid=data.loc[(data['Current_Price']>=47060)^(data['Current_Price']>=49990)].sort_values(by='Current_Price',axis=0, ascending=True, inplace=False)
most_mid
# Out:
#                                     ProductName  Stars  Ratings  Reviews  \
# 365              acer Aspire 5 Core i5 11th Gen    4.0      564       61
# 543                         HP Core i3 11th Gen    4.3     1362      142
# 498               HP 14s Intel Core i3 11th Gen    4.3      646       65
# 53                HP 15s Intel Core i3 12th Gen    4.2       39        8
# 454           Lenovo IdeaPad 3 Core i3 11th Gen    0.0        0        0
# 623              DELL INSPIRON Core i3 10th Gen    4.0      591       56
# 639              acer Aspire 5 Core i3 12th Gen    0.0        0        0
# 470             acer P2 Series Core i5 10th Gen    4.1      295       55
# 394     Infinix INBook X2 Plus Core i5 11th Gen    4.3       36        9
# 95     ASUS VivoBook 14 (2022) Core i3 12th Gen    4.1       31        5
# 619         Nokia PureBook S14 Core i5 11th Gen    4.0       95       20
# 219                       DELL Core i3 12th Gen    4.0        9        2
# ...

# %%
plt.figure(figsize=(15,8))
ax=sns.barplot(x='Current_Price',y='ProductName',data=most_mid)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [raw]
# in This visual i will show the best midrang laptops

# %%
data
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 0               Lenovo IdeaPad 3 Core i3 10th Gen    4.3        8        0
# 1    realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 2        ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 3            HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 4                  Lenovo Intel Celeron Dual Core    4.1      366       35
# ..                                            ...    ...      ...      ...
# 676       Infinix INBook X2 Plus Core i3 11th Gen    4.1      146       32
# 677         DELL Inspiron Ryzen 3 Dual Core 3250U    4.5        4        0
# 678                          MSI Core i3 12th Gen    0.0        0        0
# 679                         ASUS Core i3 10th Gen    4.7       12        0
# 680           HP Pavilion Ryzen 5 Hexa Core 5625U    4.5      199       15
#
# ...

# %%
##here shows the price_diff between current_price to MRP
plt.figure(figsize=(10,8))
sns.scatterplot(data=data, x="Current_Price", y="MRP", hue="Price_diff",palette='CMRmap',s=100)
# Out:
# <AxesSubplot:xlabel='Current_Price', ylabel='MRP'>

# %%
data
# Out:
#                                       ProductName  Stars  Ratings  Reviews  \
# 0               Lenovo IdeaPad 3 Core i3 10th Gen    4.3        8        0
# 1    realme Book(Slim) Intel Evo Core i5 11th Gen    4.4     7067      949
# 2        ASUS VivoBook 15 (2022) Core i3 10th Gen    4.3     9970      999
# 3            HP Pavilion Ryzen 5 Hexa Core AMD R5    4.4    11854     1199
# 4                  Lenovo Intel Celeron Dual Core    4.1      366       35
# ..                                            ...    ...      ...      ...
# 676       Infinix INBook X2 Plus Core i3 11th Gen    4.1      146       32
# 677         DELL Inspiron Ryzen 3 Dual Core 3250U    4.5        4        0
# 678                          MSI Core i3 12th Gen    0.0        0        0
# 679                         ASUS Core i3 10th Gen    4.7       12        0
# 680           HP Pavilion Ryzen 5 Hexa Core 5625U    4.5      199       15
#
# ...

# %% [markdown]
# # Overall top best laptops

# %%
overall_top_in_Proccessor=data.loc[(data['Proccessor']=='Intel Core i3 Processor (11th Gen)')^(data['Proccessor']=='Intel Core i5 Processor (11th Gen)')]
overall_top_in_Ram=overall_top_in_Proccessor.loc[(overall_top_in_Proccessor['Ram']=='8 GB DDR4 RAM')^(overall_top_in_Proccessor['Ram']=='4 GB DDR4 RAM')]
overall_top_in_Storage=overall_top_in_Ram.loc[(overall_top_in_Ram['Storage']=='512 GB SSD')^(overall_top_in_Ram['Storage']=='256 GB SSD')]
overall_top_in_current_price=overall_top_in_Storage.loc[(overall_top_in_Storage['Current_Price']<=54990)&(overall_top_in_Storage['Current_Price']>=47060)]
overall_top_in_Rating=overall_top_in_current_price.loc[(overall_top_in_current_price['Ratings']<=451)&(overall_top_in_current_price['Ratings']>=25)]
overall_top_lap=overall_top_in_Rating
overall_top_lap
# Out:
#                                         ProductName  Stars  Ratings  Reviews  \
# 10                        HP Intel Core i5 11th Gen    4.2       25        5
# 56                ASUS Vivobook 15 Core i5 11th Gen    4.3      121       13
# 58          ASUS Vivobook 15 Touch Core i5 11th Gen    4.3      135       14
# 63                ASUS Vivobook 15 Core i5 11th Gen    4.2      149       15
# 466                             HP Core i5 11th Gen    4.2      279       17
# 552  Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen    4.3      441       43
# 619             Nokia PureBook S14 Core i5 11th Gen    4.0       95       20
#
#      Current_Price    MRP                          Proccessor            Ram  \
# 10           52990  56903  Intel Core i5 Processor (11th Gen)  8 GB DDR4 RAM
# 56           50990  69990  Intel Core i5 Processor (11th Gen)  8 GB DDR4 RAM
# 58           51990  74990  Intel Core i5 Processor (11th Gen)  8 GB DDR4 RAM
# ...

# %%
plt.figure(figsize=(25,8))
sns.set(style='dark')
ax=sns.barplot(x='ProductName',y='Current_Price',data=overall_top_lap,palette='CMRmap')
for bars in ax.containers:
    ax.bar_label(bars,fontsize=20)

# %% [markdown]
# # In this Dataset i can find the top 6 laptops
# *HP Intel Core i5 11th Gen
# *ASUS Vivobook 15 Core i5 11th Gen
# *ASUS Vivobook 15 Touch Core i5 11th Gen
# *HP Core i5 11th Gen
# *Lenovo Ideapad Slim 3i (2021) Core i5 11th Gen
# *Nokia PureBook S14 Core i5 11th Gen
# ---Based on  overall, such-- Price, Ratings, Ram, Storages, Proccessor
